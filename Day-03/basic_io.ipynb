# %%
# Taking input
name = input("What is your name? ")
age = input("How old are you? ")

# Output using f-strings
print(f"Hello, {name}! You are {age} years old.")
# Out:
# Hello, Iqra! You are 18 years old.
