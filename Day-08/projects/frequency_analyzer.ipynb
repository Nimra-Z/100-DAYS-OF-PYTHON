# %%
# Frequency Analyzer

def analyze_frequency(input_text):
    word_frequency = {}
    char_frequency = {}

    # Word frequency
    words = input_text.split()
    for word in words:
        word_frequency[word] = word_frequency.get(word, 0) + 1

    # Character frequency
    for char in input_text:
        char_frequency[char] = char_frequency.get(char, 0) + 1

    return word_frequency, char_frequency

if __name__ == "__main__":
    text = input("Enter a long string: ")
    word_freq, char_freq = analyze_frequency(text)

    print("\nWord Frequency:")
    for word, count in word_freq.items():
        print(f"{word}: {count}")

    print("\nCharacter Frequency:")
    for char, count in char_freq.items():
        print(f"{char}: {count}")
# Out:
# Word Frequency:
# Hey!: 1
# How: 1
# are: 1
# you?: 1
#
# Character Frequency:
# H: 2
# e: 2
# y: 2
# !: 1
#  : 4
# o: 2
# w: 1
# a: 1
# r: 1
# u: 1
# ?: 1
