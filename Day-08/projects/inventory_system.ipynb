# %%
# Simple Inventory System

inventory = {}

def add_item(name, price, quantity):
    if name in inventory:
        inventory[name]['quantity'] += quantity
    else:
        inventory[name] = {'price': price, 'quantity': quantity}
    print(f"Item '{name}' added/updated.")

def update_item(name, price, quantity):
    if name in inventory:
        inventory[name]['price'] = price
        inventory[name]['quantity'] = quantity
        print(f"Item '{name}' updated.")
    else:
        print(f"Item '{name}' not found.")

def delete_item(name):
    if name in inventory:
        del inventory[name]
        print(f"Item '{name}' deleted.")
    else:
        print(f"Item '{name}' not found.")

def view_inventory():
    print("\nCurrent Inventory:")
    for name, details in inventory.items():
        print(f"Item: {name}, Price: {details['price']}, Quantity: {details['quantity']}")

if __name__ == "__main__":
    while True:
        print("\nInventory System")
        print("1. Add Item")
        print("2. Update Item")
        print("3. Delete Item")
        print("4. View Inventory")
        print("5. Exit")

        choice = int(input("Enter your choice: "))
        if choice == 1:
            name = input("Enter item name: ")
            price = float(input("Enter item price: "))
            quantity = int(input("Enter item quantity: "))
            add_item(name, price, quantity)
        elif choice == 2:
            name = input("Enter item name: ")
            price = float(input("Enter new price: "))
            quantity = int(input("Enter new quantity: "))
            update_item(name, price, quantity)
        elif choice == 3:
            name = input("Enter item name: ")
            delete_item(name)
        elif choice == 4:
            view_inventory()
        elif choice == 5:
            print("Exiting...")
            break
        else:
            print("Invalid choice. Try again.")
# Out:
# Inventory System
# 1. Add Item
# 2. Update Item
# 3. Delete Item
# 4. View Inventory
# 5. Exit
# Item 'Pencils' added/updated.
#
# Inventory System
# 1. Add Item
# 2. Update Item
# 3. Delete Item
# 4. View Inventory
# 5. Exit
# Item 'Pen' added/updated.
#
# Inventory System
# 1. Add Item
# 2. Update Item
# 3. Delete Item
# 4. View Inventory
# 5. Exit
# Item 'Books' added/updated.
#
# Inventory System
# 1. Add Item
# 2. Update Item
# 3. Delete Item
# 4. View Inventory
# 5. Exit
#
# Current Inventory:
# Item: Pencils, Price: 100.0, Quantity: 8
# Item: Pen, Price: 80.0, Quantity: 2
# Item: Books, Price: 2000.0, Quantity: 4
#
# Inventory System
# 1. Add Item
# 2. Update Item
# 3. Delete Item
# 4. View Inventory
# 5. Exit
#
# Current Inventory:
# Item: Pencils, Price: 100.0, Quantity: 8
# Item: Pen, Price: 80.0, Quantity: 2
# Item: Books, Price: 2000.0, Quantity: 4
#
# Inventory System
# 1. Add Item
# 2. Update Item
# 3. Delete Item
# 4. View Inventory
# 5. Exit
# Exiting...
