# %%
# Challenge: Sum List Function

def sum_list(numbers):
    """Returns the sum of a list of numbers."""
    return sum(numbers)

# Test the function
print(sum_list([1, 2, 3, 4]))  # Output: 10
# Out:
# 10
