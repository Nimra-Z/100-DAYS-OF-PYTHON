# %%
# Lambda Function Basics

# Define a lambda function to calculate square
square = lambda x: x ** 2
print(square(4))  # Output: 16

# Lambda function to add two numbers
add = lambda a, b: a + b
print(add(3, 5))  # Output: 8
# Out:
# 16
# 8
