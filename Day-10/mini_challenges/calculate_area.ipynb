# %%
# Challenge: Calculate Area of a Rectangle using Lambda

area = lambda length, width: length * width

# Test the lambda function
print(area(5, 10))  # Output: 50
print(area(3, 7))   # Output: 21
# Out:
# 50
# 21
